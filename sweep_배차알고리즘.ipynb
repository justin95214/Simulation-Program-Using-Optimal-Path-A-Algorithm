# %% [markdown]
# <a href="https://colab.research.google.com/github/justin95214/Simulation-Program-Using-Optimal-Path-A-Algorithm/blob/main/sweep_%EB%B0%B0%EC%B0%A8%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# sweep알고리즘
#
# copyright file :sweep 배차알고리즘 코드
#
#
# Author: Duhyeuk Chang, Soochan Choi
#
#
# Copyright (c) Developer Express. All rights reserved.

# %% [markdown]
# **1. 구글드라이브 연결하기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. 프로그램 구동**

# %% [markdown]
# **2-1. DP 업로드**

# %%
import numpy as np
import pandas as pd

import io
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-fcafd041-1fda-4aa5-9d05-53d26b854035" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fcafd041-1fda-4aa5-9d05-53d26b854035">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving DP_raw.xlsx to DP_raw (1).xlsx

# %%
df_DP = pd.read_excel(io.BytesIO(myfile['DP_raw.xlsx']))

# %% [markdown]
# **2-2. 거래처 파일 PR_week 업로드**

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-1dc95615-8f63-4770-b034-e626548b1586" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dc95615-8f63-4770-b034-e626548b1586">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving PR_week.xlsx to PR_week (1).xlsx

# %%
df_client = pd.read_excel(io.BytesIO(myfile['PR_week.xlsx']))

# %% [markdown]
# **2-3. 거래처 파일 조건 시트 업로드(파일명 : variable)**

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-4f1c0e77-808e-43d5-9aeb-8ee1e7e47108" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4f1c0e77-808e-43d5-9aeb-8ee1e7e47108">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving variable.xlsx to variable (7).xlsx

# %%
df_info  = pd.read_excel(io.BytesIO(myfile['variable.xlsx']))

# %% [markdown]
# **3. 센터 DP Info 확인하기**

# %%
df_info
# Out:
#         구분  대당 적재능력(box)  대당 운행시간(분)  평균 운행 속도(km/h)  상차시간(분)  하차시간(분)     DP
# 0   기준 데이터         300.0       500.0            70.0      5.0      5.0  대구CDP
# 1   기준 데이터         300.0       500.0            70.0      5.0      5.0  양산CDP
# 2   기준 데이터         300.0       500.0            70.0      5.0      5.0  광주CDP
# 3   기준 데이터         500.0       450.0            45.0      5.0      5.0   덕평DC
# 4   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 5   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 6   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 7   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 8   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 9   기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 10  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 11  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 12  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 13  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 14  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 15  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 16  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 17  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 18  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 19  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 20  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN
# 21  기준 데이터           NaN         NaN             NaN      NaN      NaN    NaN

# %%
week_num =['월','화','수','목','금','토','일']
for day in week_num:
  # %mkdir /content/drive/MyDrive/$day

# %mkdir /content/drive/MyDrive/Integrated_analysis
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/월’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/화’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/수’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/목’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/금’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/토’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/일’: File exists
# mkdir: cannot create directory ‘/content/drive/MyDrive/Integrated_analysis’: File exists

# %%
# df-client info
#df_client = pd.read_excel('PR_week.xlsx')
#print(df_client.head(10))

# DP address
#df_DP = pd.read_excel('DP_raw.xlsx')
#print(df_DP.head(5))
df_client = pd.merge(left=df_client, right=df_DP, on="DP", how="right")
df_client = df_client
# DF truck & time info df
#df_info = pd.read_excel('sheet_4.xlsx')
# merge the info
info_col=df_info.columns[1:]

#df_client[info_col] = df_info[info_col].iloc[0]
df_client = pd.merge(left=df_client, right=df_info, on="DP", how="right")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: FutureWarning: Passing 'suffixes' which cause duplicate columns {'구분_x'} in the result is deprecated and will raise a MergeError in a future version.
#   app.launch_new_instance()

# %% [markdown]
# # 새 섹션

# %%
week_num =['월','화','수','목','금','토','일']

at_once = []
total_max = []
# change the day
for day in week_num:
	how_long_list=[]
	total1_list =[]
	print("############################################################################################################\n")
	#Per DP, get the client info
	for DF_element in  df_DP['DP'].values.tolist():
		print("@@@@@@@@@@@@@@@@@@@@@@@@		["+ DF_element+"/"+day+"]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@\n")
		#지역 요일 별 df
		temp_df = df_client.loc[df_client['DP']==DF_element]
		print("@@@@@@@@@@@@@@@@@@@@@@@@			shape :", temp_df.shape)
		print("@@@@@@@@@@@@@@@@@@@@@@@@               small shape :", temp_df.loc[df_client[day]==1].shape)
		filter_columns = list(set(temp_df.columns.values.tolist())- set(week_num))
		filter_columns.append(day)
		temp_df = temp_df[filter_columns]	
		print(temp_df.head(5))
		temp_df['stopby'] = 0
		#temp_df =temp_df.dropna(axis=0)
		print("지역 요일 별 df shape : ",temp_df.shape)
		#print(temp_df.head(5))
		#stopby check!!
		#temp_df.to_csv("./result/test_"+DF_element+"_"+day+".csv",index=False ,encoding='utf-8-sig')
		# how many truck we need!
		# how many back to DP
		Point_list =['DP']
		Rest_time_list =[]
		Rest_Stock_list=[]
		distance = 0
		#temp_df.astype('float')
		print(temp_df.columns)
		print(temp_df.head(4))
		print(temp_df['대당 적재능력(box)'].iloc[0])
		Rest_Stock_list.append(temp_df.iloc[0]['대당 적재능력(box)'])
		Rest_time_list.append(temp_df.iloc[0]['대당 운행시간(분)'])
		current_point = 'DP'
		truck_list = []
		check = 0
		up_time = 0
		d_list=[]
		time_list=[]
		one_truck_list=[]
		Max_row =0
		col_list=[]
		T_time_list = []
		DP_count = []
		car_num =0
		how_many_car_list = []

		while(len(temp_df.loc[temp_df['stopby']==0]) >0):
			print("Point_list : ", Point_list)
			print("@@@@@@@@@@@@@@@@@@@@@@@@               check the stopby :", temp_df.loc[temp_df['stopby']==0].shape)
			#print("---------------------------")
			#print("Time list :", Rest_time_list)
			#print("---------------------------")
			#print("Stock list :", Rest_Stock_list)
			#print("---------------------------")
			#check = check+1
			print("---------------------------------------------------------------------------------------------------------------------------------\n")
			if current_point =='DP':

				temp_df['DP_y곡률값']=temp_df['Latitude']*3600
				temp_df['DP_x곡률값']=temp_df['Longitude']*3600
	
				#client curvature value
				temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
				temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

				temp_df['DP_위도거리']= abs(temp_df['x곡률값']-temp_df['DP_x곡률값'])*0.0245
				temp_df['DP_경도거리']= abs(temp_df['y곡률값']-temp_df['DP_y곡률값'])*0.0306
				temp_df['DP_운행거리'] = temp_df['DP_위도거리']+temp_df['DP_경도거리']

				#최초와 중간 회차 뒤에 경우 
				Max_distance_row = temp_df[temp_df['stopby']==0].sort_values(by='DP_운행거리', ascending=False).iloc[0]
				#print(">>운행거리 :", Max_distance_row['DP_운행거리'])

				#현재 위치 변경
				current_point = Max_distance_row['code']
				#print(check,"거리로 선정 Client: ",Max_distance_row['DP_운행거리'],current_point)
				print(">>",current_point)

				#장소 리스트 업데이트 
				Point_list.append(current_point)

				#stopby =1 check
				temp_df.loc[(temp_df['code']==current_point),'stopby']=1

				#적재량 리스트 업데이트
				current_point_stock = Max_distance_row[day].tolist()

				Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)

				print(" >> currrent_p : ",current_point,"	current_stock : ",current_point_stock)
				dist = temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
				fast = temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0]
				time =  (dist / fast)*60
				print("dist :	",dist,"/ fast :	",fast,"/ time :	",time)
							
 
				
				#남은 시간 리스트  업데이트 
				#소요 시간 = 상차 + [DP-현재 위치]이동시간 + 하차  
				Rest_time_list.append(Rest_time_list[-1] - time - temp_df.loc[temp_df['code']==current_point]['상차시간(분)'].values.tolist()[0] - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0])
				# 누적 시간 업데이트
				up_time= up_time+time+temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0] +temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]
				# 누적 거리 업데이트
				
				# 기존 거리 = 기존 거리 + [DP-현재 위치]이동시간
				distance =distance+dist
				#print("거리",temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0],"  / 속도 :",temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])
				#print("소요시간 :",(temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60)
				next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60
				# 현재 지점에서 DP까지 시간 여유
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time,"/ time :        ",next_check_time , "possible stock :	",Rest_Stock_list[-1])
				print("Point_list : ", Point_list)
				print("From :",Point_list[-2],"To :",Point_list[-1])

			elif current_point !='DP':
				#print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>y!!!!!!DP")
				#거래처 위치 
				temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
				temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

				#현재 위치 (DP >> 현재 위치 
				temp_df[current_point+'_x곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['경도(X좌표)'].values.tolist()[0]*3600
				temp_df[current_point+'_y곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['위도(Y좌표)'].values.tolist()[0]*3600

				#현재 위치와 거래처간의 계산
				temp_df[current_point+'위도거리']= abs(temp_df['x곡률값'] -temp_df[current_point+'_x곡률값'] )  *0.0245
				temp_df[current_point+'경도거리']= abs(temp_df['y곡률값'] -temp_df[current_point+'_y곡률값'] )  *0.0306
				temp_df[current_point+'운행거리'] = temp_df[current_point+'위도거리']+temp_df[current_point+'경도거리']
				#print(temp_df.head(1))			

				#print(temp_df.head(5))
				temp_df['각도']= np.degrees(np.arctan(temp_df[current_point+'위도거리']/temp_df[current_point+'경도거리']))

				#print("주행거리 : ",lowest_degree_row[current_point+'운행거리'])
				#distance =distance+ lowest_degree_row[current_point+'운행거리']


				#각도가 최적인 것을 선택
				#lowest_degree_row = temp_df[temp_df['stopby']==0].sort_values(by= '각도').iloc[0]
				tdf= temp_df[temp_df['stopby']==0]
				tdf = tdf.copy()

				lowest_degree_row = tdf.sort_values(by=current_point+'운행거리')
				print("hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh")
				#print(lowest_degree_row.head(3))

				lowest_degree_row =  lowest_degree_row.iloc[0]

				dist = lowest_degree_row[current_point+'운행거리'].tolist()
				fast = lowest_degree_row['평균 운행 속도(km/h)'].tolist()
				time =  (dist / fast)*60
				print("dist :   ",dist,"/ fast :        ",fast,"/ time :        ",time)


				#현재f 위치 변경
				current_point = lowest_degree_row['code']
				Point_list.append(current_point)

				# stopby =1 check
				temp_df.loc[(temp_df['code']==current_point),'stopby']=1
				
				#current_point = lowest_degree_row['code']

				#남은시간 리스트 업데이트 
				#  마지막 남은시간- [ 기존거래처 - 갱신 거래처]이동거리 - 하차				
				Rest_time_list.append((Rest_time_list[-1] -time - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]))

				# 누적 시간 업데이트 
				get_ff_time = temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]

				up_time= up_time + time + get_ff_time

				distance =distance+dist

				current_point_stock= lowest_degree_row[day].tolist()
				#남은 적재량 리스트 업데이트 
				Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)
				#print(" ++ currrent_p : ",current_point,"   current_stock : ",current_point_stock)
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :	 ",Rest_time_list[-1],  " / possible stock :,",Rest_Stock_list[-1],"/ possible time :        ",next_check_time)
				print("From :",Point_list[-2],"To :",Point_list[-1])

				next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60


			d_list.append(distance)

			if  Rest_time_list[-1]- next_check_time>0 and Rest_Stock_list[-1] >0  and up_time<700:
				print("조건 1",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				#print("<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<",up_time)
				if temp_df.loc[temp_df['stopby']==0].shape[0] ==0:
					truck_list.append(Point_list)
					col_list.append(len(Point_list))
					one_truck_list.append(len(Point_list)-Point_list.count("DP"))
					time_list.append(distance)
					T_time_list.append(up_time)

					DP_count.append(Point_list.count("DP")-1)
					car_num= car_num+1
					how_many_car_list.append("No. "+str(car_num))


			
				continue
			elif Rest_time_list[-1]- next_check_time>0 and Rest_Stock_list[-1] <=0 and up_time <700:
				print("조건 2",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				# 여유시간이 충분한데 capa 가 없을 때 
				current_point ='DP'
				# 회차 하고 다시 다음 회전을 위한 상차 
				Rest_time_list.append((Rest_time_list[-1]- next_check_time - temp_df.iloc[0]['상차시간(분)']))
				
				up_time = up_time+next_check_time+temp_df.iloc[0]['상차시간(분)']
				Point_list.append(current_point)
				Rest_Stock_list.append(temp_df.iloc[0]['대당 적재능력(box)'])
			   	#distance = distance + temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
				d_list.append(distance)
				print("					<<<<<<<<<<<<<회차 현황 : >>>>>>>>>>>>>>>>>>\n")
				print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1],  " / possible stock :,",Rest_Stock_list[-1],"/ possible time :        ",next_check_time)
				if up_time <700 or Rest_time_list[-1] > 0:
					print("*************************************************************************************************")
					#truck_list.append(Point_list)
					print("here here here ")
					if len(temp_df.loc[temp_df['stopby']==0]) <1:
						print("eeeeeeeeeeeeeeeweeeeeeeeeeeeeeeeeeeeeeeeewwwwwwwwwwwwwwwwwwe")
						truck_list.append(Point_list) 
						col_list.append(len(Point_list))
						one_truck_list.append(len(Point_list)-Point_list.count("DP"))
						time_list.append(distance)
						T_time_list.append(up_time)
						DP_count.append(Point_list.count("DP")-1)
						car_num= car_num+1
						how_many_car_list.append("No. "+str(car_num))
				
				elif up_time > 700 or Rest_time_list[-1] < 0 :
					
					print(" >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<\n")

					truck_list.append(Point_list)
					col_list.append(len(Point_list))
					one_truck_list.append(len(Point_list)-Point_list.count("DP"))
					time_list.append(distance)
					T_time_list.append(up_time)
					DP_count.append(Point_list.count("DP")-1)
					car_num= car_num+1
					how_many_car_list.append("No. "+str(car_num))

					current_point = 'DP'
					Point_list = ['DP']
					Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
					Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
					up_time =0


				#elif up_time <700 or Rest_time_list[-1] > 0 and len(temp_df.loc[temp_df['stopby']==0]) < 1:
					#truck_list.append(Point_list)


			elif len(temp_df.loc[temp_df['stopby']==0]) ==1:
				print("조건 4 :1개 남음 \n")
				continue


				# 여유시간이 없을 때 
			elif Rest_time_list[-1]- next_check_time <0 or Rest_time_list[-1]>0: 
				print("조건 3",Rest_time_list[-1]- next_check_time,Rest_Stock_list[-1])
				print("Left  0 count :",len(temp_df.loc[temp_df['stopby']==0]),"zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz")

				if up_time < 700 and len(temp_df.loc[temp_df['stopby']==0]) >1:
				# 여유시간이 없을 때 마지막 거래처는 갔다온다

					#거래처 위치
					temp_df['x곡률값']=temp_df['경도(X좌표)']*3600
					temp_df['y곡률값']=temp_df['위도(Y좌표)']*3600

					#현재 위치 (Cient >> 마지막 복귀
					temp_df[current_point+'_x곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['경도(X좌표)'].values.tolist()[0]*3600
					temp_df[current_point+'_y곡률값']=temp_df.loc[temp_df['code']==Point_list[-1]]['위도(Y좌표)'].values.tolist()[0]*3600

					#현재 위치와 거래처간의 계산
					temp_df[current_point+'위도거리']= abs(temp_df['x곡률값'] -temp_df[current_point+'_x곡률값'] )  *0.0245
					temp_df[current_point+'경도거리']= abs(temp_df['y곡률값'] -temp_df[current_point+'_y곡률값'] )  *0.0306
					temp_df[current_point+'운행거리'] = temp_df[current_point+'위도거리']+temp_df[current_point+'경도거리']

					#print(temp_df.head(5))
					temp_df['각도']= np.degrees(np.arctan(temp_df[current_point+'위도거리']/temp_df[current_point+'경도거리']))

					#print("주행거리 : ",lowest_degree_row[current_point+'운행거리'])
					#distance =distance+ lowest_degree_row[current_point+'운행거리']


					#각도가 최적인 것을 선택
					#lowest_degree_row = temp_df[temp_df['stopby']==0].sort_values(by='각도').iloc[0]

					tdf= temp_df[temp_df['stopby']==0]
					tdf = tdf.copy()
					lowest_degree_row = tdf.sort_values(by=current_point+'운행거리')
					lowest_degree_row =  lowest_degree_row.iloc[0]

	
					dist = lowest_degree_row[current_point+'운행거리'].tolist()
					fast = lowest_degree_row['평균 운행 속도(km/h)'].tolist()
					time =  (dist / fast)*60
					print("dist :   ",dist,"/ fast :        ",fast,"/ time :        ",time)


					#현재 위치 변경
					current_point = lowest_degree_row['code']
					Point_list.append(current_point)
					print("Point list : ", Point_list)
					# stopby =1 check
					temp_df.loc[(temp_df['code']==current_point),'stopby']=1

					#current_point = lowest_degree_row['code']

					#남은시간 리스트 업데이트
					#  마지막 남은시간- [ 기존거래처 - 갱신 거래처]이동거리 - 하차
					Rest_time_list.append(Rest_time_list[-1] -time - temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0])

					# 누적 시간 업데이트
					get_ff_time = temp_df.loc[temp_df['code']==current_point]['하차시간(분)'].values.tolist()[0]

					up_time= up_time + time + get_ff_time
					distance =distance+dist

					current_point_stock= lowest_degree_row[day].tolist()
					#남은 적재량 리스트 업데이트
					Rest_Stock_list.append(Rest_Stock_list[-1]-current_point_stock)
					#print(" ++ currrent_p : ",current_point,"   current_stock : ",current_point_stock)
					print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1], "/ possible stock :,",Rest_Stock_list[-1],"  / possible time :        ",next_check_time)
					print("From :",Point_list[-2],"To :",Point_list[-1])

					next_check_time = (temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]/temp_df.loc[temp_df['code']==current_point]['평균 운행 속도(km/h)'].values.tolist()[0])*60
					distance= distance+temp_df.loc[temp_df['code']==current_point]['DP_운행거리'].values.tolist()[0]
					# 회차  >>DP
					Rest_time_list.append(Rest_time_list[-1]-next_check_time)
					up_time= up_time+ next_check_time
					print("누적거리 :   ",distance,"/ 누적시간  :        ",up_time, "/ Rest_time :   ",Rest_time_list[-1], " / possible stock :,",Rest_Stock_list[-1],">> 복귀 완료 \n")
					print("\n")
					
				else:
					print(" >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<\n")
				

				# 회차만 
				Rest_time_list.append(Rest_time_list[-1]- next_check_time)
				print("VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV",distance)
				truck_list.append(Point_list)
				col_list.append(len(Point_list))
				one_truck_list.append(len(Point_list)-Point_list.count("DP"))
				time_list.append(distance)
				T_time_list.append(up_time)

				current_point = 'DP'
				print("From :",Point_list[-2],"To :", current_point)

				Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
				Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
				DP_count.append(Point_list.count("DP")-1)
				Point_list = ['DP']
				#one_truck_list.append(len(Point_list))
				distnace = 0
				up_time =0
				car_num= car_num+1
				how_many_car_list.append("No. "+str(car_num))


			if up_time> 700:
				distance =0
				print("here i am")
				print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>",distance)
				#one_truck_list.append(len(Point_list))
				#truck_list.append(Point_list)
				current_point = 'DP'
				Rest_Stock_list = [temp_df.iloc[0]['대당 적재능력(box)']]
				Rest_time_list = [temp_df.iloc[0]['대당 운행시간(분)']]
				up_time =0



		
		Max_row = max(col_list)
		temp_df.to_csv("temp1.csv", index=False, encoding='utf-8-sig')
		result0 = pd.DataFrame(how_many_car_list, columns=["Truck Count"])		
		result0["Region"]= DF_element
		result0["Week"]= day
		result1 = pd.DataFrame(truck_list,columns = ["Client-"+str(i) for i in range(Max_row)])
		result2 = pd.DataFrame(one_truck_list,columns=["Client Count"])
		result3 = pd.DataFrame(time_list,columns=["누적 KM"])
		per_dist =[]
		take = result3["누적 KM"].values.tolist()
		for i in range(0, len(take)):
			
			if i == 0:
				per_dist.append(take[i])
			else:
				per_dist.append((take[i]-take[i-1]))

		result3 = pd.DataFrame(per_dist,columns=["KM"])
		result5 = pd.DataFrame(T_time_list,columns=["Time"])
		result6 = pd.DataFrame(DP_count,columns=["DP를 몇 번"])
		
		result4 = pd.concat([result0,result5,result3,result2,result6, result1],axis=1)
		result4.to_csv("/content/drive/MyDrive/"+day+"/"+DF_element+day+"complete.csv",encoding='utf-8-sig', index=False)
		#print(result)
		for f_row in result4.values.tolist():
			print(f_row)
			how_long_list.append(len(f_row)-6)
			total1_list.append(f_row)
	print("max :", max(how_long_list))
	t_colums_list = ["Truck Count","Region","Week","Time","KM","Client Count"]
	client_list = ["Client-"+str(i) for i in range(max(how_long_list))]

	t_colums_list= t_colums_list + client_list
	print(t_colums_list)
	result_t =  pd.DataFrame(total1_list, columns = t_colums_list)
	result_t.to_csv("/content/drive/MyDrive/Integrated_analysis/"+"Interal_Region"+day+"analysis.csv"+"Interal_Region"+day+"analysis.csv",encoding='utf-8-sig', index=False)
	
	total_max.append(max(how_long_list))
	for i in total1_list:
		at_once.append(i)

DR_columns_list = ["Truck Count","Region","Week","Time","KM","Client Count"]
client_list1 = ["Position-"+str(i) for i in range(max(total_max))]
DR_columns_list = DR_columns_list + client_list1 
DR_df = pd.DataFrame(at_once, columns=DR_columns_list)

DR_df.to_csv("/content/drive/MyDrive/Integrated_analysis/"+"Interal_Region_Week_analysis.csv",encoding='utf-8-sig', index=False)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Left  0 count : 29 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.211407385863012 / fast :         45.0 / time :         6.948543181150683
# Point list :  ['DP', '안양지사', '군포지사']
# 누적거리 :    1615.211430848169 / 누적시간  :         97.5247960830493 / Rest_time :    352.4752039169507 / possible stock :, nan   / possible time :         75.57625290189861
# From : 안양지사 To : 군포지사
# 누적거리 :    1669.7629028415756 / 누적시간  :         170.2600920742583 / Rest_time :    279.7399079257417  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1669.7629028415756
# From : 안양지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (28, 132)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 진접지사
#  >> currrent_p :  진접지사 	current_stock :  nan
# dist :	 56.449335361390204 / fast :	 45.0 / time :	 75.2657804818536
# 누적거리 :    1726.2122382029659 / 누적시간  :         85.2657804818536 / time :         75.2657804818536 possible stock :	 nan
# Point_list :  ['DP', '진접지사']
# From : DP To : 진접지사
# 조건 3 289.4684390362928 nan
# Left  0 count : 27 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.029853636135355 / fast :         45.0 / time :         12.039804848180474
# Point list :  ['DP', '진접지사', '덕소지사']
# 누적거리 :    1735.2420918391012 / 누적시간  :         102.30558533003406 / Rest_time :    347.6944146699659 / possible stock :, nan   / possible time :         75.2657804818536
# From : 진접지사 To : 덕소지사
# 누적거리 :    1782.661573564356 / 누적시간  :         165.5315609637072 / Rest_time :    284.4684390362928  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1782.661573564356
# From : 진접지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (26, 137)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구의지사
#  >> currrent_p :  구의지사 	current_stock :  nan
# dist :	 56.24757536340658 / fast :	 45.0 / time :	 74.99676715120877
# 누적거리 :    1838.9091489277628 / 누적시간  :         84.99676715120877 / time :         74.99676715120877 possible stock :	 nan
# Point_list :  ['DP', '구의지사']
# From : DP To : 구의지사
# 조건 3 290.0064656975825 nan
# Left  0 count : 25 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.811067308303935 / fast :         45.0 / time :         6.414756411071913
# Point list :  ['DP', '구의지사', '강동지사']
# 누적거리 :    1843.7202162360668 / 누적시간  :         96.41152356228068 / Rest_time :    353.58847643771935 / possible stock :, nan   / possible time :         74.99676715120877
# From : 구의지사 To : 강동지사
# 누적거리 :    1895.1567242911694 / 누적시간  :         164.99353430241754 / Rest_time :    285.0064656975825  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 1895.1567242911694
# From : 구의지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (24, 142)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구리지사
#  >> currrent_p :  구리지사 	current_stock :  nan
# dist :	 55.637459418980754 / fast :	 45.0 / time :	 74.18327922530767
# 누적거리 :    1950.7941837101503 / 누적시간  :         84.18327922530767 / time :         74.18327922530767 possible stock :	 nan
# Point_list :  ['DP', '구리지사']
# From : DP To : 구리지사
# 조건 3 291.63344154938466 nan
# Left  0 count : 23 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.253265072578301 / fast :         45.0 / time :         12.337686763437736
# Point list :  ['DP', '구리지사', '송파오금지사']
# 누적거리 :    1960.0474487827287 / 누적시간  :         101.5209659887454 / Rest_time :    348.4790340112546 / possible stock :, nan   / possible time :         74.18327922530767
# From : 구리지사 To : 송파오금지사
# 누적거리 :    2008.9438172532884 / 누적시간  :         166.7161239494917 / Rest_time :    283.2838760505083  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2008.9438172532884
# From : 구리지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (22, 147)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 군포당정지사
#  >> currrent_p :  군포당정지사 	current_stock :  nan
# dist :	 54.79776917469279 / fast :	 45.0 / time :	 73.06369223292373
# 누적거리 :    2063.741586427981 / 누적시간  :         83.06369223292373 / time :         73.06369223292373 possible stock :	 nan
# Point_list :  ['DP', '군포당정지사']
# From : DP To : 군포당정지사
# 조건 3 293.8726155341526 nan
# Left  0 count : 21 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.830358688754853 / fast :         45.0 / time :         13.107144918339804
# Point list :  ['DP', '군포당정지사', '서수원지사']
# 누적거리 :    2073.571945116736 / 누적시간  :         101.17083715126353 / Rest_time :    348.8291628487365 / possible stock :, nan   / possible time :         73.06369223292373
# From : 군포당정지사 To : 서수원지사
# 누적거리 :    2118.539355602674 / 누적시간  :         161.12738446584746 / Rest_time :    288.87261553415254  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2118.539355602674
# From : 군포당정지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (20, 152)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 봉담지사
#  >> currrent_p :  봉담지사 	current_stock :  nan
# dist :	 48.740903743411444 / fast :	 45.0 / time :	 64.98787165788193
# 누적거리 :    2167.280259346085 / 누적시간  :         74.98787165788193 / time :         64.98787165788193 possible stock :	 nan
# Point_list :  ['DP', '봉담지사']
# From : DP To : 봉담지사
# 조건 3 310.0242566842362 nan
# Left  0 count : 19 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.399443087814268 / fast :         45.0 / time :         7.199257450419023
# Point list :  ['DP', '봉담지사', '화성송산지사']
# 누적거리 :    2172.6797024338994 / 누적시간  :         87.18712910830095 / Rest_time :    362.8128708916991 / possible stock :, nan   / possible time :         64.98787165788193
# From : 봉담지사 To : 화성송산지사
# 누적거리 :    2216.209218031536 / 누적시간  :         145.2264832384826 / Rest_time :    304.7735167615175  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2216.209218031536
# From : 봉담지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (18, 157)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 하남지사
#  >> currrent_p :  하남지사 	current_stock :  nan
# dist :	 43.93590276954561 / fast :	 45.0 / time :	 58.581203692727485
# 누적거리 :    2260.1451208010812 / 누적시간  :         68.58120369272748 / time :         58.581203692727485 possible stock :	 nan
# Point_list :  ['DP', '하남지사']
# From : DP To : 하남지사
# 조건 3 322.837592614545 nan
# Left  0 count : 17 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    1.57114469388898 / fast :         45.0 / time :         2.0948595918519732
# Point list :  ['DP', '하남지사', '하남유니트']
# 누적거리 :    2261.7162654949702 / 누적시간  :         75.67606328457946 / Rest_time :    374.32393671542053 / possible stock :, nan   / possible time :         58.581203692727485
# From : 하남지사 To : 하남유니트
# 누적거리 :    2304.0810235706267 / 누적시간  :         132.16240738545497 / Rest_time :    317.83759261454503  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2304.0810235706267
# From : 하남지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (16, 162)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 성남중원지사
#  >> currrent_p :  성남중원지사 	current_stock :  nan
# dist :	 43.63743333436237 / fast :	 45.0 / time :	 58.1832444458165
# 누적거리 :    2347.718456904989 / 누적시간  :         68.1832444458165 / time :         58.1832444458165 possible stock :	 nan
# Point_list :  ['DP', '성남중원지사']
# From : DP To : 성남중원지사
# 조건 3 323.633511108367 nan
# Left  0 count : 15 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.415296746750475 / fast :         45.0 / time :         7.220395662333967
# Point list :  ['DP', '성남중원지사', '성남지사']
# 누적거리 :    2353.1337536517394 / 누적시간  :         80.40364010815047 / Rest_time :    369.59635989184954 / possible stock :, nan   / possible time :         58.1832444458165
# From : 성남중원지사 To : 성남지사
# 누적거리 :    2391.5084817783118 / 누적시간  :         131.56994427691342 / Rest_time :    318.4300557230866  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2391.5084817783118
# From : 성남중원지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (14, 167)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 화성지사
#  >> currrent_p :  화성지사 	current_stock :  nan
# dist :	 42.872281211177345 / fast :	 45.0 / time :	 57.16304161490313
# 누적거리 :    2434.380762989489 / 누적시간  :         67.16304161490314 / time :         57.16304161490313 possible stock :	 nan
# Point_list :  ['DP', '화성지사']
# From : DP To : 화성지사
# 조건 3 325.6739167701937 nan
# Left  0 count : 13 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.450898153888088 / fast :         45.0 / time :         7.267864205184117
# Point list :  ['DP', '화성지사', '남수원지사']
# 누적거리 :    2439.831661143377 / 누적시간  :         79.43090582008725 / Rest_time :    370.5690941799127 / possible stock :, nan   / possible time :         57.16304161490313
# From : 화성지사 To : 남수원지사
# 누적거리 :    2479.3923535038607 / 누적시간  :         132.17849563406557 / Rest_time :    317.8215043659344  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2479.3923535038607
# From : 화성지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (12, 172)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 동수원지사
#  >> currrent_p :  동수원지사 	current_stock :  nan
# dist :	 41.21711524960381 / fast :	 45.0 / time :	 54.95615366613841
# 누적거리 :    2520.6094687534646 / 누적시간  :         64.95615366613842 / time :         54.95615366613841 possible stock :	 nan
# Point_list :  ['DP', '동수원지사']
# From : DP To : 동수원지사
# 조건 3 330.0876926677232 nan
# Left  0 count : 11 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.394891409304764 / fast :         45.0 / time :         12.526521879073018
# Point list :  ['DP', '동수원지사', '신갈지사']
# 누적거리 :    2530.0043601627694 / 누적시간  :         82.48267554521144 / Rest_time :    367.5173244547886 / possible stock :, nan   / possible time :         54.95615366613841
# From : 동수원지사 To : 신갈지사
# 누적거리 :    2561.8265840030685 / 누적시간  :         124.91230733227682 / Rest_time :    325.0876926677232  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2561.8265840030685
# From : 동수원지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (10, 177)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 용인수지지사
#  >> currrent_p :  용인수지지사 	current_stock :  nan
# dist :	 37.01275773557551 / fast :	 45.0 / time :	 49.350343647434016
# 누적거리 :    2598.839341738644 / 누적시간  :         59.350343647434016 / time :         49.350343647434016 possible stock :	 nan
# Point_list :  ['DP', '용인수지지사']
# From : DP To : 용인수지지사
# 조건 3 341.299312705132 nan
# Left  0 count : 9 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    4.945689300635946 / fast :         45.0 / time :         6.594252400847928
# Point list :  ['DP', '용인수지지사', '용인지사']
# 누적거리 :    2603.78503103928 / 누적시간  :         70.94459604828194 / Rest_time :    379.05540395171806 / possible stock :, nan   / possible time :         49.350343647434016
# From : 용인수지지사 To : 용인지사
# 누적거리 :    2635.85209947422 / 누적시간  :         113.70068729486803 / Rest_time :    336.29931270513197  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2635.85209947422
# From : 용인수지지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (8, 182)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 신구지사
#  >> currrent_p :  신구지사 	current_stock :  nan
# dist :	 31.29041170114486 / fast :	 45.0 / time :	 41.720548934859806
# 누적거리 :    2667.1425111753647 / 누적시간  :         51.720548934859806 / time :         41.720548934859806 possible stock :	 nan
# Point_list :  ['DP', '신구지사']
# From : DP To : 신구지사
# 조건 3 356.55890213028033 nan
# Left  0 count : 7 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    5.058467900821319 / fast :         45.0 / time :         6.744623867761759
# Point list :  ['DP', '신구지사', '기흥지사']
# 누적거리 :    2672.200979076186 / 누적시간  :         63.46517280262157 / Rest_time :    386.53482719737843 / possible stock :, nan   / possible time :         41.720548934859806
# From : 신구지사 To : 기흥지사
# 누적거리 :    2698.4329228765096 / 누적시간  :         98.44109786971961 / Rest_time :    351.5589021302804  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2698.4329228765096
# From : 신구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (6, 187)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 태전지사
#  >> currrent_p :  태전지사 	current_stock :  nan
# dist :	 31.06847476053077 / fast :	 45.0 / time :	 41.42463301404103
# 누적거리 :    2729.5013976370406 / 누적시간  :         51.42463301404103 / time :         41.42463301404103 possible stock :	 nan
# Point_list :  ['DP', '태전지사']
# From : DP To : 태전지사
# 조건 3 357.15073397191793 nan
# Left  0 count : 5 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    2.3186306570759796 / fast :         45.0 / time :         3.091507542767973
# Point list :  ['DP', '태전지사', '경안지사']
# 누적거리 :    2731.8200282941166 / 누적시간  :         59.516140556809 / Rest_time :    390.48385944319097 / possible stock :, nan   / possible time :         41.42463301404103
# From : 태전지사 To : 경안지사
# 누적거리 :    2760.5698723975715 / 누적시간  :         97.84926602808204 / Rest_time :    352.15073397191793  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2760.5698723975715
# From : 태전지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (4, 192)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 용인처인지사
#  >> currrent_p :  용인처인지사 	current_stock :  nan
# dist :	 29.962626806106833 / fast :	 45.0 / time :	 39.95016907480911
# 누적거리 :    2790.5324992036785 / 누적시간  :         49.95016907480911 / time :         39.95016907480911 possible stock :	 nan
# Point_list :  ['DP', '용인처인지사']
# From : DP To : 용인처인지사
# 조건 3 360.09966185038184 nan
# Left  0 count : 3 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.36722458119716 / fast :         45.0 / time :         12.489632774929547
# Point list :  ['DP', '용인처인지사', '용인모현지사']
# 누적거리 :    2799.8997237848757 / 누적시간  :         67.43980184973866 / Rest_time :    382.5601981502614 / possible stock :, nan   / possible time :         39.95016907480911
# From : 용인처인지사 To : 용인모현지사
# 누적거리 :    2821.4961120963067 / 누적시간  :         96.23498626497995 / Rest_time :    353.7650137350201  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2821.4961120963067
# From : 용인처인지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (2, 197)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 용인동백지사
#  >> currrent_p :  용인동백지사 	current_stock :  nan
# dist :	 26.097938064703698 / fast :	 45.0 / time :	 34.79725075293827
# 누적거리 :    2847.5940501610103 / 누적시간  :         44.79725075293827 / time :         34.79725075293827 possible stock :	 nan
# Point_list :  ['DP', '용인동백지사']
# From : DP To : 용인동백지사
# 조건 4 :1개 남음
#
# Point_list :  ['DP', '용인동백지사']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 197)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# dist :    19.935191212453766 / fast :         45.0 / time :         26.580254949938354
# 누적거리 :    2867.529241373464 / 누적시간  :         76.37750570287662 / Rest_time :	  373.62249429712335  / possible stock :, nan / possible time :         34.79725075293827
# From : 용인동백지사 To : 오포지사
# 조건 3 342.1293438581219 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 2867.529241373464
# From : 용인동백지사 To : DP
# ['No. 1', '덕평DC', '수', 328.05773764958656, 234.79330323718995, 2, 0, 'DP', '서김포지사', '일산지사']
# ['No. 2', '덕평DC', '수', 313.99943813966456, 224.24957860474842, 2, 0, 'DP', '파주지사', '파주운정지사']
# ['No. 3', '덕평DC', '수', 305.55116264520007, 217.91337198390005, 2, 0, 'DP', '일산동구지사', '김포지사']
# ['No. 4', '덕평DC', '수', 294.0859069020055, 209.31443017650417, 2, 0, 'DP', '탄현지사', '고양지사']
# ['No. 5', '덕평DC', '수', 293.1293918971749, 208.5970439228812, 2, 0, 'DP', '서인천지사', '성수지사']
# ['No. 6', '덕평DC', '수', 283.2010337154253, 201.15077528656911, 2, 0, 'DP', '춘천지사', '남양주지사']
# ['No. 7', '덕평DC', '수', 202.76865521447755, 140.82649141085813, 2, 0, 'DP', '원주지사', '이천지사']
# ['No. 8', '덕평DC', '수', 170.297118884308, 116.4728391632309, 2, 0, 'DP', '광진지사', '잠실지사']
# ['No. 9', '덕평DC', '수', 170.2600920742583, 116.4450690556937, 2, 0, 'DP', '안양지사', '군포지사']
# ['No. 10', '덕평DC', '수', 165.5315609637072, 112.89867072278048, 2, 0, 'DP', '진접지사', '덕소지사']
# ['No. 11', '덕평DC', '수', 164.99353430241754, 112.49515072681334, 2, 0, 'DP', '구의지사', '강동지사']
# ['No. 12', '덕평DC', '수', 166.7161239494917, 113.787092962119, 2, 0, 'DP', '구리지사', '송파오금지사']
# ['No. 13', '덕평DC', '수', 161.12738446584746, 109.59553834938538, 2, 0, 'DP', '군포당정지사', '서수원지사']
# ['No. 14', '덕평DC', '수', 145.2264832384826, 97.66986242886196, 2, 0, 'DP', '봉담지사', '화성송산지사']
# ['No. 15', '덕평DC', '수', 132.16240738545497, 87.87180553909093, 2, 0, 'DP', '하남지사', '하남유니트']
# ['No. 16', '덕평DC', '수', 131.56994427691342, 87.42745820768505, 2, 0, 'DP', '성남중원지사', '성남지사']
# ['No. 17', '덕평DC', '수', 132.17849563406557, 87.88387172554894, 2, 0, 'DP', '화성지사', '남수원지사']
# ['No. 18', '덕평DC', '수', 124.91230733227682, 82.43423049920784, 2, 0, 'DP', '동수원지사', '신갈지사']
# ['No. 19', '덕평DC', '수', 113.70068729486803, 74.02551547115127, 2, 0, 'DP', '용인수지지사', '용인지사']
# ['No. 20', '덕평DC', '수', 98.44109786971961, 62.58082340228975, 2, 0, 'DP', '신구지사', '기흥지사']
# ['No. 21', '덕평DC', '수', 97.84926602808204, 62.13694952106198, 2, 0, 'DP', '태전지사', '경안지사']
# ['No. 22', '덕평DC', '수', 96.23498626497995, 60.92623969873512, 2, 0, 'DP', '용인처인지사', '용인모현지사']
# ['No. 23', '덕평DC', '수', 76.37750570287662, 46.033129277157514, 2, 0, 'DP', '용인동백지사', '오포지사']
# @@@@@@@@@@@@@@@@@@@@@@@@		[양산CDP/수]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (2, 84)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 84)
#     Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 11  128.981744  128.981744  128.981744  34.0  34.0  34.0           100.0
# 12  128.981744  128.981744  128.981744  34.0  34.0  34.0           100.0
#
#     대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 11           200.0           300.0           100.0  ...         450.0
# 12           200.0           300.0           100.0  ...         450.0
#
#     대당 운행시간(분)_x  대당 운행시간(분)_x                주소_x                주소_x  \
# 11         500.0         500.0  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229
# 12         500.0         500.0  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229
#
#                   주소_x     DP                  주소  대당 운행시간(분)   수
# 11  경남 양산시 물금읍 제방로 229  양산CDP  경남 양산시 물금읍 제방로 229       500.0 NaN
# 12  경남 양산시 물금읍 제방로 229  양산CDP  경남 양산시 물금읍 제방로 229       500.0 NaN
#
# [2 rows x 78 columns]
# 지역 요일 별 df shape :  (2, 79)
# Index(['Latitude_x', 'Latitude_x', 'Latitude_x', '구간_y', '구간_y', '구간_y',
#        '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_x',
#        '대당 적재능력(box)_x', '대당 적재능력(box)_x', 'Latitude', '구분_y', '구분_y', '구분_y',
#        '구분_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y',
#        '상차시간(분)', '하차시간(분)_x', '하차시간(분)_x', '하차시간(분)_x', 'Longitude_y',
#        'Longitude_y', 'Longitude_y', '상차시간(분)_y', '상차시간(분)_y', '상차시간(분)_y',
#        '하차시간(분)_y', '하차시간(분)_y', '하차시간(분)_y', 'Longitude_x', 'Longitude_x',
#        'Longitude_x', 'code', '구분_x', '구분_x', '구분_x', '구분_x', 'Longitude',
#        '대당 적재능력(box)', '평균 운행 속도(km/h)', 'citydistrict', '경도(X좌표)', '하차시간(분)',
#        '구간_x', '구간_x', '구간_x', '상차시간(분)_x', '상차시간(분)_x', '상차시간(분)_x',
#        'Latitude_y', 'Latitude_y', 'Latitude_y', 'Addressline', '위도(Y좌표)',
#        '대당 운행시간(분)_y', '대당 운행시간(분)_y', '대당 운행시간(분)_y', '주소_y', '주소_y', '주소_y',
#        '구간', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x',
#        '대당 운행시간(분)_x', '대당 운행시간(분)_x', '대당 운행시간(분)_x', '주소_x', '주소_x', '주소_x',
#        'DP', '주소', '대당 운행시간(분)', '수', 'stopby'],
#       dtype='object')
#     Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 11  128.981744  128.981744  128.981744  34.0  34.0  34.0           100.0
# 12  128.981744  128.981744  128.981744  34.0  34.0  34.0           100.0
#
#     대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 11           200.0           300.0           100.0  ...         500.0
# 12           200.0           300.0           100.0  ...         500.0
#
#     대당 운행시간(분)_x                주소_x                주소_x                주소_x  \
# 11         500.0  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229
# 12         500.0  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229  경남 양산시 물금읍 제방로 229
#
#        DP                  주소  대당 운행시간(분)   수  stopby
# 11  양산CDP  경남 양산시 물금읍 제방로 229       500.0 NaN       0
# 12  양산CDP  경남 양산시 물금읍 제방로 229       500.0 NaN       0
#
# [2 rows x 79 columns]
# 300.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (2, 79)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 동양산지사
#  >> currrent_p :  동양산지사 	current_stock :  nan
# dist :	 49.12448038673067 / fast :	 70.0 / time :	 42.10669747434057
# 누적거리 :    49.12448038673067 / 누적시간  :         52.10669747434057 / time :         42.10669747434057 possible stock :	 nan
# Point_list :  ['DP', '동양산지사']
# From : DP To : 동양산지사
# 조건 4 :1개 남음
#
# Point_list :  ['DP', '동양산지사']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 86)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# dist :    18.54990161915168 / fast :         70.0 / time :         15.899915673558581
# 누적거리 :    67.67438200588235 / 누적시간  :         73.00661314789915 / Rest_time :	  426.9933868521008  / possible stock :, nan / possible time :         42.10669747434057
# From : 동양산지사 To : 양산지사
# 조건 3 400.7866050513188 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 67.67438200588235
# From : 동양산지사 To : DP
# ['No. 1', '양산CDP', '수', 73.00661314789915, 67.67438200588235, 2, 0, 'DP', '동양산지사', '양산지사']
# @@@@@@@@@@@@@@@@@@@@@@@@		[광주CDP/수]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (6, 84)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 84)
#     Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 13  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 14  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 15  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 16  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 17  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
#
#     대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 13           200.0           300.0           100.0  ...         450.0
# 14           200.0           300.0           100.0  ...         450.0
# 15           200.0           300.0           100.0  ...         450.0
# 16           200.0           300.0           100.0  ...         450.0
# 17           200.0           300.0           100.0  ...         450.0
#
#     대당 운행시간(분)_x  대당 운행시간(분)_x                  주소_x                  주소_x  \
# 13         500.0         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 14         500.0         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 15         500.0         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 16         500.0         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 17         500.0         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
#
#                     주소_x     DP                    주소  대당 운행시간(분)   수
# 13  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN
# 14  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN
# 15  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN
# 16  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN
# 17  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN
#
# [5 rows x 78 columns]
# 지역 요일 별 df shape :  (6, 79)
# Index(['Latitude_x', 'Latitude_x', 'Latitude_x', '구간_y', '구간_y', '구간_y',
#        '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_x',
#        '대당 적재능력(box)_x', '대당 적재능력(box)_x', 'Latitude', '구분_y', '구분_y', '구분_y',
#        '구분_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y',
#        '상차시간(분)', '하차시간(분)_x', '하차시간(분)_x', '하차시간(분)_x', 'Longitude_y',
#        'Longitude_y', 'Longitude_y', '상차시간(분)_y', '상차시간(분)_y', '상차시간(분)_y',
#        '하차시간(분)_y', '하차시간(분)_y', '하차시간(분)_y', 'Longitude_x', 'Longitude_x',
#        'Longitude_x', 'code', '구분_x', '구분_x', '구분_x', '구분_x', 'Longitude',
#        '대당 적재능력(box)', '평균 운행 속도(km/h)', 'citydistrict', '경도(X좌표)', '하차시간(분)',
#        '구간_x', '구간_x', '구간_x', '상차시간(분)_x', '상차시간(분)_x', '상차시간(분)_x',
#        'Latitude_y', 'Latitude_y', 'Latitude_y', 'Addressline', '위도(Y좌표)',
#        '대당 운행시간(분)_y', '대당 운행시간(분)_y', '대당 운행시간(분)_y', '주소_y', '주소_y', '주소_y',
#        '구간', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x',
#        '대당 운행시간(분)_x', '대당 운행시간(분)_x', '대당 운행시간(분)_x', '주소_x', '주소_x', '주소_x',
#        'DP', '주소', '대당 운행시간(분)', '수', 'stopby'],
#       dtype='object')
#     Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 13  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 14  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 15  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
# 16  126.876292  126.876292  126.876292  56.0  56.0  56.0           100.0
#
#     대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 13           200.0           300.0           100.0  ...         500.0
# 14           200.0           300.0           100.0  ...         500.0
# 15           200.0           300.0           100.0  ...         500.0
# 16           200.0           300.0           100.0  ...         500.0
#
#     대당 운행시간(분)_x                  주소_x                  주소_x  \
# 13         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 14         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 15         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
# 16         500.0  광주광역시 광산구 연산동 1144번지  광주광역시 광산구 연산동 1144번지
#
#                     주소_x     DP                    주소  대당 운행시간(분)   수  stopby
# 13  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN       0
# 14  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN       0
# 15  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN       0
# 16  광주광역시 광산구 연산동 1144번지  광주CDP  광주광역시 광산구 연산동 1144번지       500.0 NaN       0
#
# [4 rows x 79 columns]
# 300.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (6, 79)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 전주지사
#  >> currrent_p :  전주지사 	current_stock :  nan
# dist :	 85.26746917162707 / fast :	 70.0 / time :	 73.08640214710891
# 누적거리 :    85.26746917162707 / 누적시간  :         83.08640214710891 / time :         73.08640214710891 possible stock :	 nan
# Point_list :  ['DP', '전주지사']
# From : DP To : 전주지사
# 조건 3 343.8271957057822 nan
# Left  0 count : 5 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    28.04218699028362 / fast :         70.0 / time :         24.03616027738596
# Point list :  ['DP', '전주지사', '익산지사']
# 누적거리 :    113.3096561619107 / 누적시간  :         112.12256242449487 / Rest_time :    387.87743757550516 / possible stock :, nan   / possible time :         73.08640214710891
# From : 전주지사 To : 익산지사
# 누적거리 :    196.71683497617434 / 누적시간  :         183.614429979578 / Rest_time :    316.38557002042205  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 196.71683497617434
# From : 전주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (4, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 목포지사
#  >> currrent_p :  목포지사 	current_stock :  nan
# dist :	 79.87376626934469 / fast :	 70.0 / time :	 68.46322823086687
# 누적거리 :    276.590601245519 / 누적시간  :         78.46322823086687 / time :         68.46322823086687 possible stock :	 nan
# Point_list :  ['DP', '목포지사']
# From : DP To : 목포지사
# 조건 3 353.0735435382662 nan
# Left  0 count : 3 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    72.37603593954039 / fast :         70.0 / time :         62.036602233891756
# Point list :  ['DP', '목포지사', '서광주지사']
# 누적거리 :    348.96663718505937 / 누적시간  :         145.49983046475865 / Rest_time :    354.50016953524135 / possible stock :, nan   / possible time :         68.46322823086687
# From : 목포지사 To : 서광주지사
# 누적거리 :    357.26699010794266 / 누적시간  :         152.6144186843729 / Rest_time :    347.38558131562706  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 357.26699010794266
# From : 목포지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (2, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 광주광산지사
#  >> currrent_p :  광주광산지사 	current_stock :  nan
# dist :	 7.2553670601485205 / fast :	 70.0 / time :	 6.218886051555875
# 누적거리 :    364.52235716809116 / 누적시간  :         16.218886051555874 / time :         6.218886051555875 possible stock :	 nan
# Point_list :  ['DP', '광주광산지사']
# From : DP To : 광주광산지사
# 조건 4 :1개 남음
#
# Point_list :  ['DP', '광주광산지사']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# dist :    11.143153182815523 / fast :         70.0 / time :         9.55127415669902
# 누적거리 :    375.6655103509067 / 누적시간  :         30.770160208254893 / Rest_time :	  469.22983979174506  / possible stock :, nan / possible time :         6.218886051555875
# From : 광주광산지사 To : 광주북구지사
# 조건 3 465.8974516866019 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 375.6655103509067
# From : 광주광산지사 To : DP
# ['No. 1', '광주CDP', '수', 183.614429979578, 196.71683497617434, 2, 0, 'DP', '전주지사', '익산지사']
# ['No. 2', '광주CDP', '수', 152.6144186843729, 160.55015513176832, 2, 0, 'DP', '목포지사', '서광주지사']
# ['No. 3', '광주CDP', '수', 30.770160208254893, 18.398520242964025, 2, 0, 'DP', '광주광산지사', '광주북구지사']
# @@@@@@@@@@@@@@@@@@@@@@@@		[대구CDP/수]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (11, 84)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 84)
#    Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 0  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 1  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 2  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 3  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 4  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
#
#    대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 0           200.0           300.0           100.0  ...         450.0
# 1           200.0           300.0           100.0  ...         450.0
# 2           200.0           300.0           100.0  ...         450.0
# 3           200.0           300.0           100.0  ...         450.0
# 4           200.0           300.0           100.0  ...         450.0
#
#    대당 운행시간(분)_x  대당 운행시간(분)_x            주소_x            주소_x            주소_x  \
# 0         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 1         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 2         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 3         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 4         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
#
#       DP              주소  대당 운행시간(분)   수
# 0  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 1  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 2  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 3  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 4  대구CDP  경북 구미시 공단동 294       500.0 NaN
#
# [5 rows x 78 columns]
# 지역 요일 별 df shape :  (11, 79)
# Index(['Latitude_x', 'Latitude_x', 'Latitude_x', '구간_y', '구간_y', '구간_y',
#        '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_x',
#        '대당 적재능력(box)_x', '대당 적재능력(box)_x', 'Latitude', '구분_y', '구분_y', '구분_y',
#        '구분_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y',
#        '상차시간(분)', '하차시간(분)_x', '하차시간(분)_x', '하차시간(분)_x', 'Longitude_y',
#        'Longitude_y', 'Longitude_y', '상차시간(분)_y', '상차시간(분)_y', '상차시간(분)_y',
#        '하차시간(분)_y', '하차시간(분)_y', '하차시간(분)_y', 'Longitude_x', 'Longitude_x',
#        'Longitude_x', 'code', '구분_x', '구분_x', '구분_x', '구분_x', 'Longitude',
#        '대당 적재능력(box)', '평균 운행 속도(km/h)', 'citydistrict', '경도(X좌표)', '하차시간(분)',
#        '구간_x', '구간_x', '구간_x', '상차시간(분)_x', '상차시간(분)_x', '상차시간(분)_x',
#        'Latitude_y', 'Latitude_y', 'Latitude_y', 'Addressline', '위도(Y좌표)',
#        '대당 운행시간(분)_y', '대당 운행시간(분)_y', '대당 운행시간(분)_y', '주소_y', '주소_y', '주소_y',
#        '구간', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x',
#        '대당 운행시간(분)_x', '대당 운행시간(분)_x', '대당 운행시간(분)_x', '주소_x', '주소_x', '주소_x',
#        'DP', '주소', '대당 운행시간(분)', '수', 'stopby'],
#       dtype='object')
#    Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 0  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 1  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 2  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 3  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
#
#    대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 0           200.0           300.0           100.0  ...         500.0
# 1           200.0           300.0           100.0  ...         500.0
# 2           200.0           300.0           100.0  ...         500.0
# 3           200.0           300.0           100.0  ...         500.0
#
#    대당 운행시간(분)_x            주소_x            주소_x            주소_x     DP  \
# 0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 1         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 2         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 3         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
#
#                주소  대당 운행시간(분)   수  stopby
# 0  경북 구미시 공단동 294       500.0 NaN       0
# 1  경북 구미시 공단동 294       500.0 NaN       0
# 2  경북 구미시 공단동 294       500.0 NaN       0
# 3  경북 구미시 공단동 294       500.0 NaN       0
#
# [4 rows x 79 columns]
# 300.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (11, 79)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 울산지사
#  >> currrent_p :  울산지사 	current_stock :  nan
# dist :	 116.09121795378181 / fast :	 70.0 / time :	 99.50675824609868
# 누적거리 :    116.09121795378181 / 누적시간  :         109.50675824609868 / time :         99.50675824609868 possible stock :	 nan
# Point_list :  ['DP', '울산지사']
# From : DP To : 울산지사
# 조건 3 290.98648350780263 nan
# Left  0 count : 10 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    17.154098381987023 / fast :         70.0 / time :         14.70351289884602
# Point list :  ['DP', '울산지사', '울산남구지사']
# 누적거리 :    133.24531633576882 / 누적시간  :         129.2102711449447 / Rest_time :    370.7897288550553 / possible stock :, nan   / possible time :         99.50675824609868
# From : 울산지사 To : 울산남구지사
# 누적거리 :    232.18243590756362 / 누적시간  :         214.01351649219737 / Rest_time :    285.9864835078026  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 232.18243590756362
# From : 울산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (9, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 포항북구지사
#  >> currrent_p :  포항북구지사 	current_stock :  nan
# dist :	 102.78691310628633 / fast :	 70.0 / time :	 88.10306837681686
# 누적거리 :    334.96934901385 / 누적시간  :         98.10306837681686 / time :         88.10306837681686 possible stock :	 nan
# Point_list :  ['DP', '포항북구지사']
# From : DP To : 포항북구지사
# 조건 3 313.7938632463663 nan
# Left  0 count : 8 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    16.684971185158346 / fast :         70.0 / time :         14.301403872992868
# Point list :  ['DP', '포항북구지사', '포항지사']
# 누적거리 :    351.65432019900834 / 누적시간  :         117.40447224980973 / Rest_time :    382.5955277501903 / possible stock :, nan   / possible time :         88.10306837681686
# From : 포항북구지사 To : 포항지사
# 누적거리 :    437.7562621201363 / 누적시간  :         191.2061367536337 / Rest_time :    308.7938632463663  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 437.7562621201363
# From : 포항북구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (7, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 안동지사
#  >> currrent_p :  안동지사 	current_stock :  nan
# dist :	 75.48018415848873 / fast :	 70.0 / time :	 64.69730070727604
# 누적거리 :    513.236446278625 / 누적시간  :         74.69730070727604 / time :         64.69730070727604 possible stock :	 nan
# Point_list :  ['DP', '안동지사']
# From : DP To : 안동지사
# 조건 3 360.6053985854479 nan
# Left  0 count : 6 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    68.46673468928599 / fast :         70.0 / time :         58.68577259081656
# Point list :  ['DP', '안동지사', '대구신평지사']
# 누적거리 :    581.703180967911 / 누적시간  :         138.3830732980926 / Rest_time :    361.6169267019074 / possible stock :, nan   / possible time :         64.69730070727604
# From : 안동지사 To : 대구신평지사
# 누적거리 :    596.2578369650569 / 누적시간  :         150.85849272421765 / Rest_time :    349.1415072757824  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 596.2578369650569
# From : 안동지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (5, 102)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구미지사
#  >> currrent_p :  구미지사 	current_stock :  nan
# dist :	 33.76998555135387 / fast :	 70.0 / time :	 28.94570190116046
# 누적거리 :    630.0278225164108 / 누적시간  :         38.94570190116046 / time :         28.94570190116046 possible stock :	 nan
# Point_list :  ['DP', '구미지사']
# From : DP To : 구미지사
# 조건 3 432.10859619767905 nan
# Left  0 count : 4 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    28.621668481414815 / fast :         70.0 / time :         24.532858698355557
# Point list :  ['DP', '구미지사', '서대구지사']
# 누적거리 :    658.6494909978255 / 누적시간  :         68.47856059951602 / Rest_time :    431.521439400484 / possible stock :, nan   / possible time :         28.94570190116046
# From : 구미지사 To : 서대구지사
# 누적거리 :    677.6577470736675 / 누적시간  :         84.77135152166629 / Rest_time :    415.2286484783337  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 677.6577470736675
# From : 구미지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (3, 107)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 동대구지사
#  >> currrent_p :  동대구지사 	current_stock :  nan
# dist :	 10.830067688871566 / fast :	 70.0 / time :	 9.282915161889914
# 누적거리 :    688.4878147625391 / 누적시간  :         19.282915161889914 / time :         9.282915161889914 possible stock :	 nan
# Point_list :  ['DP', '동대구지사']
# From : DP To : 동대구지사
# 조건 3 471.4341696762202 nan
# Left  0 count : 2 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.747857810702353 / fast :         70.0 / time :         8.355306694887732
# Point list :  ['DP', '동대구지사', '남대구지사']
# 누적거리 :    698.2356725732415 / 누적시간  :         32.63822185677765 / Rest_time :    467.36177814322235 / possible stock :, nan   / possible time :         9.282915161889914
# From : 동대구지사 To : 남대구지사
# 누적거리 :    704.6781921752951 / 누적시간  :         38.160381515680776 / Rest_time :    461.8396184843192  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 704.6781921752951
# From : 동대구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 112)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 북대구지사
#  >> currrent_p :  북대구지사 	current_stock :  nan
# dist :	 3.8640054581374335 / fast :	 70.0 / time :	 3.3120046784035146
# 누적거리 :    708.5421976334325 / 누적시간  :         13.312004678403515 / time :         3.3120046784035146 possible stock :	 nan
# Point_list :  ['DP', '북대구지사']
# From : DP To : 북대구지사
# 조건 3 483.37599064319295 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 708.5421976334325
# From : DP To : DP
# ['No. 1', '대구CDP', '수', 214.01351649219737, 232.18243590756362, 2, 0, 'DP', '울산지사', '울산남구지사']
# ['No. 2', '대구CDP', '수', 191.2061367536337, 205.57382621257267, 2, 0, 'DP', '포항북구지사', '포항지사']
# ['No. 3', '대구CDP', '수', 150.85849272421765, 158.50157484492058, 2, 0, 'DP', '안동지사', '대구신평지사']
# ['No. 4', '대구CDP', '수', 84.77135152166629, 81.39991010861058, 2, 0, 'DP', '구미지사', '서대구지사']
# ['No. 5', '대구CDP', '수', 38.160381515680776, 27.020445101627615, 2, 0, 'DP', '동대구지사', '남대구지사']
# ['No. 6', '대구CDP', '수', 13.312004678403515, 3.864005458137399, 1, 0, 'DP', '북대구지사', None]
# max : 4
# ['Truck Count', 'Region', 'Week', 'Time', 'KM', 'Client Count', 'Client-0', 'Client-1', 'Client-2', 'Client-3']
# ############################################################################################################
#
# @@@@@@@@@@@@@@@@@@@@@@@@		[덕평DC/목]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (46, 84)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 84)
#     Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 19  127.372741  127.372741  127.372741  78.0  78.0  78.0           100.0
# 20  127.372741  127.372741  127.372741  78.0  78.0  78.0           100.0
# 21  127.372741  127.372741  127.372741  78.0  78.0  78.0           100.0
# 22  127.372741  127.372741  127.372741  78.0  78.0  78.0           100.0
# 23  127.372741  127.372741  127.372741  78.0  78.0  78.0           100.0
#
#     대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 19           200.0           300.0           100.0  ...         450.0
# 20           200.0           300.0           100.0  ...         450.0
# 21           200.0           300.0           100.0  ...         450.0
# 22           200.0           300.0           100.0  ...         450.0
# 23           200.0           300.0           100.0  ...         450.0
#
#     대당 운행시간(분)_x  대당 운행시간(분)_x                 주소_x                 주소_x  \
# 19         500.0         400.0  경기도 이천시 마장면 서이천로 91  경기도 이천시 마장면 서이천로 91
# 20         500.0         400.0  경기도 이천시 마장면 서이천로 91  경기도 이천시 마장면 서이천로 91
# 21         500.0         400.0  경기도 이천시 마장면 서이천로 91  경기도 이천시 마장면 서이천로 91
# 22         500.0         400.0  경기도 이천시 마장면 서이천로 91  경기도 이천시 마장면 서이천로 91
# 23         500.0         400.0  경기도 이천시 마장면 서이천로 91  경기도 이천시 마장면 서이천로 91
#
#                    주소_x    DP                   주소  대당 운행시간(분)   목
# 19  경기도 이천시 마장면 서이천로 91  덕평DC  경기도 이천시 마장면 서이천로 91       450.0 NaN
# 20  경기도 이천시 마장면 서이천로 91  덕평DC  경기도 이천시 마장면 서이천로 91       450.0 NaN
# 21  경기도 이천시 마장면 서이천로 91  덕평DC  경기도 이천시 마장면 서이천로 91       450.0 NaN
# 22  경기도 이천시 마장면 서이천로 91  덕평DC  경기도 이천시 마장면 서이천로 91       450.0 NaN
# 23  경기도 이천시 마장면 서이천로 91  덕평DC  경기도 이천시 마장면 서이천로 91       450.0 NaN
#
# [5 rows x 78 columns]
# 지역 요일 별 df shape :  (46, 79)
# Index(['Latitude_x', 'Latitude_x', 'Latitude_x', '구간_y', '구간_y', '구간_y',
#        '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_x',
#        '대당 적재능력(box)_x', '대당 적재능력(box)_x', 'Latitude', '구분_y', '구분_y', '구분_y',
#        '구분_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y',
#        '상차시간(분)', '하차시간(분)_x', '하차시간(분)_x', '하차시간(분)_x', 'Longitude_y',
#        'Longitude_y', 'Longitude_y', '상차시간(분)_y', '상차시간(분)_y', '상차시간(분)_y',
#        '하차시간(분)_y', '하차시간(분)_y', '하차시간(분)_y', 'Longitude_x', 'Longitude_x',
#        'Longitude_x', 'code', '구분_x', '구분_x', '구분_x', '구분_x', 'Longitude',
#        '대당 적재능력(box)', '평균 운행 속도(km/h)', 'citydistrict', '경도(X좌표)', '하차시간(분)',
# ...
# 300.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (6, 79)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 전주지사
#  >> currrent_p :  전주지사 	current_stock :  nan
# dist :	 85.26746917162707 / fast :	 70.0 / time :	 73.08640214710891
# 누적거리 :    85.26746917162707 / 누적시간  :         83.08640214710891 / time :         73.08640214710891 possible stock :	 nan
# Point_list :  ['DP', '전주지사']
# From : DP To : 전주지사
# 조건 3 343.8271957057822 nan
# Left  0 count : 5 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    28.04218699028362 / fast :         70.0 / time :         24.03616027738596
# Point list :  ['DP', '전주지사', '익산지사']
# 누적거리 :    113.3096561619107 / 누적시간  :         112.12256242449487 / Rest_time :    387.87743757550516 / possible stock :, nan   / possible time :         73.08640214710891
# From : 전주지사 To : 익산지사
# 누적거리 :    196.71683497617434 / 누적시간  :         183.614429979578 / Rest_time :    316.38557002042205  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 196.71683497617434
# From : 전주지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (4, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 목포지사
#  >> currrent_p :  목포지사 	current_stock :  nan
# dist :	 79.87376626934469 / fast :	 70.0 / time :	 68.46322823086687
# 누적거리 :    276.590601245519 / 누적시간  :         78.46322823086687 / time :         68.46322823086687 possible stock :	 nan
# Point_list :  ['DP', '목포지사']
# From : DP To : 목포지사
# 조건 3 353.0735435382662 nan
# Left  0 count : 3 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    72.37603593954039 / fast :         70.0 / time :         62.036602233891756
# Point list :  ['DP', '목포지사', '서광주지사']
# 누적거리 :    348.96663718505937 / 누적시간  :         145.49983046475865 / Rest_time :    354.50016953524135 / possible stock :, nan   / possible time :         68.46322823086687
# From : 목포지사 To : 서광주지사
# 누적거리 :    357.26699010794266 / 누적시간  :         152.6144186843729 / Rest_time :    347.38558131562706  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 357.26699010794266
# From : 목포지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (2, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 광주광산지사
#  >> currrent_p :  광주광산지사 	current_stock :  nan
# dist :	 7.2553670601485205 / fast :	 70.0 / time :	 6.218886051555875
# 누적거리 :    364.52235716809116 / 누적시간  :         16.218886051555874 / time :         6.218886051555875 possible stock :	 nan
# Point_list :  ['DP', '광주광산지사']
# From : DP To : 광주광산지사
# 조건 4 :1개 남음
#
# Point_list :  ['DP', '광주광산지사']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# hhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# dist :    11.143153182815523 / fast :         70.0 / time :         9.55127415669902
# 누적거리 :    375.6655103509067 / 누적시간  :         30.770160208254893 / Rest_time :	  469.22983979174506  / possible stock :, nan / possible time :         6.218886051555875
# From : 광주광산지사 To : 광주북구지사
# 조건 3 465.8974516866019 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 375.6655103509067
# From : 광주광산지사 To : DP
# ['No. 1', '광주CDP', '일', 183.614429979578, 196.71683497617434, 2, 0, 'DP', '전주지사', '익산지사']
# ['No. 2', '광주CDP', '일', 152.6144186843729, 160.55015513176832, 2, 0, 'DP', '목포지사', '서광주지사']
# ['No. 3', '광주CDP', '일', 30.770160208254893, 18.398520242964025, 2, 0, 'DP', '광주광산지사', '광주북구지사']
# @@@@@@@@@@@@@@@@@@@@@@@@		[대구CDP/일]		@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#
# @@@@@@@@@@@@@@@@@@@@@@@@			shape : (11, 84)
# @@@@@@@@@@@@@@@@@@@@@@@@               small shape : (0, 84)
#    Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 0  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 1  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 2  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 3  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 4  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
#
#    대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 0           200.0           300.0           100.0  ...         450.0
# 1           200.0           300.0           100.0  ...         450.0
# 2           200.0           300.0           100.0  ...         450.0
# 3           200.0           300.0           100.0  ...         450.0
# 4           200.0           300.0           100.0  ...         450.0
#
#    대당 운행시간(분)_x  대당 운행시간(분)_x            주소_x            주소_x            주소_x  \
# 0         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 1         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 2         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 3         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
# 4         500.0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294
#
#       DP              주소  대당 운행시간(분)   일
# 0  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 1  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 2  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 3  대구CDP  경북 구미시 공단동 294       500.0 NaN
# 4  대구CDP  경북 구미시 공단동 294       500.0 NaN
#
# [5 rows x 78 columns]
# 지역 요일 별 df shape :  (11, 79)
# Index(['Latitude_x', 'Latitude_x', 'Latitude_x', '구간_y', '구간_y', '구간_y',
#        '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_y', '대당 적재능력(box)_x',
#        '대당 적재능력(box)_x', '대당 적재능력(box)_x', 'Latitude', '구분_y', '구분_y', '구분_y',
#        '구분_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y', '평균 운행 속도(km/h)_y',
#        '상차시간(분)', '하차시간(분)_x', '하차시간(분)_x', '하차시간(분)_x', 'Longitude_y',
#        'Longitude_y', 'Longitude_y', '상차시간(분)_y', '상차시간(분)_y', '상차시간(분)_y',
#        '하차시간(분)_y', '하차시간(분)_y', '하차시간(분)_y', 'Longitude_x', 'Longitude_x',
#        'Longitude_x', 'code', '구분_x', '구분_x', '구분_x', '구분_x', 'Longitude',
#        '대당 적재능력(box)', '평균 운행 속도(km/h)', 'citydistrict', '경도(X좌표)', '하차시간(분)',
#        '구간_x', '구간_x', '구간_x', '상차시간(분)_x', '상차시간(분)_x', '상차시간(분)_x',
#        'Latitude_y', 'Latitude_y', 'Latitude_y', 'Addressline', '위도(Y좌표)',
#        '대당 운행시간(분)_y', '대당 운행시간(분)_y', '대당 운행시간(분)_y', '주소_y', '주소_y', '주소_y',
#        '구간', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x', '평균 운행 속도(km/h)_x',
#        '대당 운행시간(분)_x', '대당 운행시간(분)_x', '대당 운행시간(분)_x', '주소_x', '주소_x', '주소_x',
#        'DP', '주소', '대당 운행시간(분)', '일', 'stopby'],
#       dtype='object')
#    Latitude_x  Latitude_x  Latitude_x  구간_y  구간_y  구간_y  대당 적재능력(box)_y  \
# 0  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 1  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 2  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
# 3  128.595722  128.595722  128.595722  12.0  12.0  12.0           100.0
#
#    대당 적재능력(box)_y  대당 적재능력(box)_y  대당 적재능력(box)_x  ...  대당 운행시간(분)_x  \
# 0           200.0           300.0           100.0  ...         500.0
# 1           200.0           300.0           100.0  ...         500.0
# 2           200.0           300.0           100.0  ...         500.0
# 3           200.0           300.0           100.0  ...         500.0
#
#    대당 운행시간(분)_x            주소_x            주소_x            주소_x     DP  \
# 0         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 1         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 2         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
# 3         500.0  경북 구미시 공단동 294  경북 구미시 공단동 294  경북 구미시 공단동 294  대구CDP
#
#                주소  대당 운행시간(분)   일  stopby
# 0  경북 구미시 공단동 294       500.0 NaN       0
# 1  경북 구미시 공단동 294       500.0 NaN       0
# 2  경북 구미시 공단동 294       500.0 NaN       0
# 3  경북 구미시 공단동 294       500.0 NaN       0
#
# [4 rows x 79 columns]
# 300.0
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (11, 79)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 울산지사
#  >> currrent_p :  울산지사 	current_stock :  nan
# dist :	 116.09121795378181 / fast :	 70.0 / time :	 99.50675824609868
# 누적거리 :    116.09121795378181 / 누적시간  :         109.50675824609868 / time :         99.50675824609868 possible stock :	 nan
# Point_list :  ['DP', '울산지사']
# From : DP To : 울산지사
# 조건 3 290.98648350780263 nan
# Left  0 count : 10 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    17.154098381987023 / fast :         70.0 / time :         14.70351289884602
# Point list :  ['DP', '울산지사', '울산남구지사']
# 누적거리 :    133.24531633576882 / 누적시간  :         129.2102711449447 / Rest_time :    370.7897288550553 / possible stock :, nan   / possible time :         99.50675824609868
# From : 울산지사 To : 울산남구지사
# 누적거리 :    232.18243590756362 / 누적시간  :         214.01351649219737 / Rest_time :    285.9864835078026  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 232.18243590756362
# From : 울산지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (9, 92)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 포항북구지사
#  >> currrent_p :  포항북구지사 	current_stock :  nan
# dist :	 102.78691310628633 / fast :	 70.0 / time :	 88.10306837681686
# 누적거리 :    334.96934901385 / 누적시간  :         98.10306837681686 / time :         88.10306837681686 possible stock :	 nan
# Point_list :  ['DP', '포항북구지사']
# From : DP To : 포항북구지사
# 조건 3 313.7938632463663 nan
# Left  0 count : 8 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    16.684971185158346 / fast :         70.0 / time :         14.301403872992868
# Point list :  ['DP', '포항북구지사', '포항지사']
# 누적거리 :    351.65432019900834 / 누적시간  :         117.40447224980973 / Rest_time :    382.5955277501903 / possible stock :, nan   / possible time :         88.10306837681686
# From : 포항북구지사 To : 포항지사
# 누적거리 :    437.7562621201363 / 누적시간  :         191.2061367536337 / Rest_time :    308.7938632463663  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 437.7562621201363
# From : 포항북구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (7, 97)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 안동지사
#  >> currrent_p :  안동지사 	current_stock :  nan
# dist :	 75.48018415848873 / fast :	 70.0 / time :	 64.69730070727604
# 누적거리 :    513.236446278625 / 누적시간  :         74.69730070727604 / time :         64.69730070727604 possible stock :	 nan
# Point_list :  ['DP', '안동지사']
# From : DP To : 안동지사
# 조건 3 360.6053985854479 nan
# Left  0 count : 6 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    68.46673468928599 / fast :         70.0 / time :         58.68577259081656
# Point list :  ['DP', '안동지사', '대구신평지사']
# 누적거리 :    581.703180967911 / 누적시간  :         138.3830732980926 / Rest_time :    361.6169267019074 / possible stock :, nan   / possible time :         64.69730070727604
# From : 안동지사 To : 대구신평지사
# 누적거리 :    596.2578369650569 / 누적시간  :         150.85849272421765 / Rest_time :    349.1415072757824  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 596.2578369650569
# From : 안동지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (5, 102)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 구미지사
#  >> currrent_p :  구미지사 	current_stock :  nan
# dist :	 33.76998555135387 / fast :	 70.0 / time :	 28.94570190116046
# 누적거리 :    630.0278225164108 / 누적시간  :         38.94570190116046 / time :         28.94570190116046 possible stock :	 nan
# Point_list :  ['DP', '구미지사']
# From : DP To : 구미지사
# 조건 3 432.10859619767905 nan
# Left  0 count : 4 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    28.621668481414815 / fast :         70.0 / time :         24.532858698355557
# Point list :  ['DP', '구미지사', '서대구지사']
# 누적거리 :    658.6494909978255 / 누적시간  :         68.47856059951602 / Rest_time :    431.521439400484 / possible stock :, nan   / possible time :         28.94570190116046
# From : 구미지사 To : 서대구지사
# 누적거리 :    677.6577470736675 / 누적시간  :         84.77135152166629 / Rest_time :    415.2286484783337  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 677.6577470736675
# From : 구미지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (3, 107)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 동대구지사
#  >> currrent_p :  동대구지사 	current_stock :  nan
# dist :	 10.830067688871566 / fast :	 70.0 / time :	 9.282915161889914
# 누적거리 :    688.4878147625391 / 누적시간  :         19.282915161889914 / time :         9.282915161889914 possible stock :	 nan
# Point_list :  ['DP', '동대구지사']
# From : DP To : 동대구지사
# 조건 3 471.4341696762202 nan
# Left  0 count : 2 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
# dist :    9.747857810702353 / fast :         70.0 / time :         8.355306694887732
# Point list :  ['DP', '동대구지사', '남대구지사']
# 누적거리 :    698.2356725732415 / 누적시간  :         32.63822185677765 / Rest_time :    467.36177814322235 / possible stock :, nan   / possible time :         9.282915161889914
# From : 동대구지사 To : 남대구지사
# 누적거리 :    704.6781921752951 / 누적시간  :         38.160381515680776 / Rest_time :    461.8396184843192  / possible stock :, nan >> 복귀 완료
#
#
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 704.6781921752951
# From : 동대구지사 To : DP
# Point_list :  ['DP']
# @@@@@@@@@@@@@@@@@@@@@@@@               check the stopby : (1, 112)
# ---------------------------------------------------------------------------------------------------------------------------------
#
# >> 북대구지사
#  >> currrent_p :  북대구지사 	current_stock :  nan
# dist :	 3.8640054581374335 / fast :	 70.0 / time :	 3.3120046784035146
# 누적거리 :    708.5421976334325 / 누적시간  :         13.312004678403515 / time :         3.3120046784035146 possible stock :	 nan
# Point_list :  ['DP', '북대구지사']
# From : DP To : 북대구지사
# 조건 3 483.37599064319295 nan
# Left  0 count : 0 zzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz
#  >>>>>>>>>>>>>>>>>>>>>회차 시 누적 시간 이 700 초과 여서 운행 종료 <<<<<<<<<<<<<<<<<<<<<<<<<<<
#
# VVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVVV 708.5421976334325
# From : DP To : DP
# ['No. 1', '대구CDP', '일', 214.01351649219737, 232.18243590756362, 2, 0, 'DP', '울산지사', '울산남구지사']
# ['No. 2', '대구CDP', '일', 191.2061367536337, 205.57382621257267, 2, 0, 'DP', '포항북구지사', '포항지사']
# ['No. 3', '대구CDP', '일', 150.85849272421765, 158.50157484492058, 2, 0, 'DP', '안동지사', '대구신평지사']
# ['No. 4', '대구CDP', '일', 84.77135152166629, 81.39991010861058, 2, 0, 'DP', '구미지사', '서대구지사']
# ['No. 5', '대구CDP', '일', 38.160381515680776, 27.020445101627615, 2, 0, 'DP', '동대구지사', '남대구지사']
# ['No. 6', '대구CDP', '일', 13.312004678403515, 3.864005458137399, 1, 0, 'DP', '북대구지사', None]
# max : 4
# ['Truck Count', 'Region', 'Week', 'Time', 'KM', 'Client Count', 'Client-0', 'Client-1', 'Client-2', 'Client-3']
